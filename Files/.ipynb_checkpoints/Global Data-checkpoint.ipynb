# %%
# %matplotlib inline
import pycountry
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt 
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-03507a519e5e> in <module>
#       6 import requests
#       7 import matplotlib.pyplot as plt
# ----> 8 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#To get the names of countries
list = [country.name for country in pycountry.countries]
#To get the CountryCode
list1=[country.alpha_2 for country in pycountry.countries]

# %%
#Countries_Data = pd.DataFrame(list,columns={"Country"})
Countries_Data=pd.DataFrame(list1,columns={"CountryCode"})
Countries_Data
# Out:
#     CountryCode
# 0            AW
# 1            AF
# 2            AO
# 3            AI
# 4            AX
# ..          ...
# 244          WS
# 245          YE
# 246          ZA
# 247          ZM
# 248          ZW
#
# [249 rows x 1 columns]

# %%
#Reference for the API documentation: https://covid19api.com/

url = "https://api.covid19api.com/summary"
response = requests.get("https://api.covid19api.com/summary").json()
#Fetching the global summary data from the API.
Global_Data = dict(response["Global"])
Global_df = pd.DataFrame([Global_Data])
Global = Global_df.transpose()            #Transposed the data frame.
Global.reset_index(inplace=True)
Global = Global.rename(columns={0:"Count","index":"Category"})

Global.sort_values('Category',ascending=False,inplace=True)
Global_New=Global.head(2)

# %%
Global_New
# Out:
#          Category     Count
# 5  TotalRecovered  10131931
# 3     TotalDeaths    673161

# %%
Counts = Global_New["Count"]
Category = Global_New["Category"]

# %%
#Created a pie chart 
fig1, ax1 = plt.subplots(figsize=(10,5))    #https://stackoverflow.com/questions/49199164/increasing-pie-chart-size-with-matplotlib-radius-parameter-appears-to-do-nothi 
NUM_COLORS = len(Counts)
labels = [labels for labels in Category]
def autopct_generator(limit):
    """Remove percent on small slices."""
    def inner_autopct(pct):
        return ('%.2f%%' % pct) if pct > limit else ''
    return inner_autopct

theme = plt.get_cmap('bwr')
ax1.set_prop_cycle("color", [theme(1. * i / len(Counts)) for i in range(len(Counts))])
box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 1.3, box.height])

_, _, autotexts = ax1.pie(
    Counts, autopct=autopct_generator(7), startangle=90, radius=1.8 * 1000,frame=True)
for autotext in autotexts:
    autotext.set_weight('bold')
    autotext.set_size('large')
ax1.axis('equal')
total = sum(Counts)
plt.legend(
    loc='upper left',
    labels=['%s, %1.1f%%' % (
        l, (float(s) / total) * 100) for l, s in zip(labels, Counts)],
    prop={'size': 12},
    bbox_to_anchor=(0.0, 1),
    bbox_transform=fig1.transFigure
)

fig1.savefig("GLOBAL SUMMARY IMAGES/New_chart.png")

# %% [markdown]
# ### Analysis:
# ##### This pie chart shows the global data of Total Recovered & Total Deaths till now. We can see that the total recovered cases are more than the total deaths.This means that still we have a hope to control the pandemic in future if proper steps are taken

# %%
#Fetching the global data for all the countries from our API.
New = response["Countries"]
Data = pd.DataFrame(New)
Merge = pd.merge(Countries_Data,Data,on="CountryCode",how="inner")

# %%
Merge
# Out:
#     CountryCode               Country                  Slug  NewConfirmed  \
# 0            AF           Afghanistan           afghanistan            71
# 1            AO                Angola                angola            31
# 2            AL               Albania               albania            92
# 3            AD               Andorra               andorra             4
# 4            AE  United Arab Emirates  united-arab-emirates           302
# ..          ...                   ...                   ...           ...
# 180          VN              Viet Nam               vietnam            50
# 181          YE                 Yemen                 yemen            15
# 182          ZA          South Africa          south-africa         11046
# 183          ZM                Zambia                zambia           306
# 184          ZW              Zimbabwe              zimbabwe           213
#
#      TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0             36542          0         1271            82           25471
# 1              1109          3           51            94             395
# 2              5197          4          154            53            2883
# 3               922          0           52             2             806
# 4             60223          2          349           424           53626
# ..              ...        ...          ...           ...             ...
# 180             509          0            0             4             373
# 181            1726          2          487             7             856
# 182          482169        315         7812         11634          309601
# 183            5555          3          149             4            3289
# 184            3092         12           53            37             924
#
#                      Date Premium
# 0    2020-07-31T22:10:40Z      {}
# 1    2020-07-31T22:10:40Z      {}
# 2    2020-07-31T22:10:40Z      {}
# 3    2020-07-31T22:10:40Z      {}
# 4    2020-07-31T22:10:40Z      {}
# ..                    ...     ...
# 180  2020-07-31T22:10:40Z      {}
# 181  2020-07-31T22:10:40Z      {}
# 182  2020-07-31T22:10:40Z      {}
# 183  2020-07-31T22:10:40Z      {}
# 184  2020-07-31T22:10:40Z      {}
#
# [185 rows x 11 columns]

# %%
#Extracting the required field for our analysis.
Total_Summary = Merge[["Country","CountryCode","TotalConfirmed","TotalRecovered","TotalDeaths"]]
Total_Summary
# Out:
#                   Country CountryCode  TotalConfirmed  TotalRecovered  \
# 0             Afghanistan          AF           36542           25471
# 1                  Angola          AO            1109             395
# 2                 Albania          AL            5197            2883
# 3                 Andorra          AD             922             806
# 4    United Arab Emirates          AE           60223           53626
# ..                    ...         ...             ...             ...
# 180              Viet Nam          VN             509             373
# 181                 Yemen          YE            1726             856
# 182          South Africa          ZA          482169          309601
# 183                Zambia          ZM            5555            3289
# 184              Zimbabwe          ZW            3092             924
#
#      TotalDeaths
# 0           1271
# 1             51
# 2            154
# 3             52
# 4            349
# ..           ...
# 180            0
# 181          487
# 182         7812
# 183          149
# 184           53
#
# [185 rows x 5 columns]

# %%
#Getting the lat and lng data from lat and lng.csv file.
lat_lng = pd.read_csv("../files/lat and lng.csv")
Country_lat_lng=lat_lng[["country_code","latitude","longitude"]]
Country_lat_lng
# Out:
#     country_code   latitude  longitude
# 0             AD  42.546245   1.601554
# 1             AE  23.424076  53.847818
# 2             AF  33.939110  67.709953
# 3             AG  17.060816 -61.796428
# 4             AI  18.220554 -63.068615
# ..           ...        ...        ...
# 240           YE  15.552727  48.516388
# 241           YT -12.827500  45.166244
# 242           ZA -30.559482  22.937506
# 243           ZM -13.133897  27.849332
# 244           ZW -19.015438  29.154857
#
# [245 rows x 3 columns]

# %%
Country_lat_lng.rename(columns={"country_code": "CountryCode"},inplace=True)
Country_lat_lng
# Out:
# C:\Users\sunandan\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     CountryCode   latitude  longitude
# 0            AD  42.546245   1.601554
# 1            AE  23.424076  53.847818
# 2            AF  33.939110  67.709953
# 3            AG  17.060816 -61.796428
# 4            AI  18.220554 -63.068615
# ..          ...        ...        ...
# 240          YE  15.552727  48.516388
# 241          YT -12.827500  45.166244
# 242          ZA -30.559482  22.937506
# 243          ZM -13.133897  27.849332
# 244          ZW -19.015438  29.154857
#
# [245 rows x 3 columns]

# %%
#Merging the data frames 
New_df = pd.merge(Country_lat_lng,Total_Summary,on="CountryCode",how="inner")
New_df
# Out:
#     CountryCode   latitude   longitude               Country  TotalConfirmed  \
# 0            AD  42.546245    1.601554               Andorra             922
# 1            AE  23.424076   53.847818  United Arab Emirates           60223
# 2            AF  33.939110   67.709953           Afghanistan           36542
# 3            AG  17.060816  -61.796428   Antigua and Barbuda              91
# 4            AL  41.153332   20.168331               Albania            5197
# ..          ...        ...         ...                   ...             ...
# 178          VN  14.058324  108.277199              Viet Nam             509
# 179          YE  15.552727   48.516388                 Yemen            1726
# 180          ZA -30.559482   22.937506          South Africa          482169
# 181          ZM -13.133897   27.849332                Zambia            5555
# 182          ZW -19.015438   29.154857              Zimbabwe            3092
#
#      TotalRecovered  TotalDeaths
# 0               806           52
# 1             53626          349
# 2             25471         1271
# 3                67            3
# 4              2883          154
# ..              ...          ...
# 178             373            0
# 179             856          487
# 180          309601         7812
# 181            3289          149
# 182             924           53
#
# [183 rows x 7 columns]

# %%
multiplot=Total_Summary.plot(kind='bar',figsize=(100,10))
multiplot.set_xticklabels(Total_Summary["Country"],rotation=90)
plt.show()
plt.tight_layout()
#plt.savefig("GLOBAL SUMMARY IMAGES/barplot.png")
fig = plt.gcf()
fig.set_size_inches(8,3)
plt.show()
plt.savefig("GLOBAL SUMMARY IMAGES/barplot.png")

# %%
bins = [0,10000,50000,100000,250000,1000000,2000000,2500000,5000000]

# Create the names for the five bins
group_names = ["<9999","10000-49999","50000-99999","100000-249999","250000-999999","1000000-1999999","2000000-2499999",">2500000"]

out=pd.cut(New_df["TotalConfirmed"],bins,labels=group_names,include_lowest=True)
axis = out.value_counts(sort=False)
#fig,ax=plt.subplots()
totals=[]
ax=axis.plot.bar(rot=45, color="orange", figsize=(8,5))
for i in ax.patches:
    totals.append(i.get_height())
total = sum(totals)
    
# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_x()-.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

#ax.invert_yaxis()
plt.title("Countries within different ranges of confirmed cases",fontweight=6,fontsize=15,color="black")
plt.xlabel("Total Confirmed Cases")
plt.ylabel("No of Countries")
plt.grid(True, 'major', 'y', ls='--', lw=.5, c='k', alpha=.3)
plt.savefig("GLOBAL SUMMARY IMAGES/Total_Confirmed_bar.png")

# %% [markdown]
# ## Analysis:
# ### 55% of the total no of countries had less than 99999 of confirmed cases.
# ## This analysis was done to show the statistics of countries globally.

# %%
New_df.head()

# %% [markdown]
# ### Plotting the world map with confirmed and recovery cases for each country
# ###### The map will be displayed using notebook.

# %%
import plotly.tools as tl
import plotly.express as px
import plotly.offline as py
from plotly.offline import iplot
import plotly.graph_objects as go
from plotly.subplots import make_subplots

#World Map with Total Confirmed and Total Recovered
fig = px.scatter_mapbox(New_df, title="World Map with Total Confirmedand Total Recovered",  lat="latitude", lon="longitude", hover_name="Country", hover_data=["TotalRecovered", "TotalConfirmed"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(title_x=0.5,
    title_y=0.95,
    mapbox={"style": "carto-positron", "center": {"lon": 2, "lat" : 47}, "zoom": 4.8},
    margin={"l": 0, "r": 0, "b": 0, "t": 80})
fig.show()
fig.write_html('first_figure2.html', auto_open=True)
